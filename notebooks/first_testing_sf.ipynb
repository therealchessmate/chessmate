# %%
from stockfish import Stockfish
stockfish_path = r'/Users/daanbarsukoffponiatowsky/Projects/chessmate/stockfish_bin/official_stockfish'

# %%
stockfish = Stockfish(stockfish_path)

# %%
# Out:
# 'e2e4'
