# %%
from engines.stockfish import StockfishWrapper
stockfish_path = r'/Users/daanbarsukoffponiatowsky/Projects/chessmate/stockfish_bin/patched_stockfish'
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from engines.stockfish import StockfishWrapper
#       2 stockfish_path = r'/Users/daanbarsukoffponiatowsky/Projects/chessmate/stockfish_bin/patched_stockfish'
#
# ModuleNotFoundError: No module named 'engines'

# %%
sf = StockfishWrapper(stockfish_path)
sf.get_evaluation_breakdown()
# Out:
# {'type': 'cp', 'value': 64}

# %%
sf.get_best_move()
# Out:
# 'e2e4'
